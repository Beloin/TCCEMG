# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

import matplotlib as mpl

# %%
mpl.rcParams['figure.dpi'] = 300

# %%
base = pd.read_csv("./1_raw.csv", header=None)
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280000 entries, 0 to 1279999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   0       1280000 non-null  float64
#  1   1       1280000 non-null  float64
#  2   2       1280000 non-null  float64
#  3   3       1280000 non-null  float64
# dtypes: float64(4)
# memory usage: 39.1 MB

# %%
1280000/2000
# Out:
# 640.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
base.head()
# Out:
#           0         1         2         3
# 0  8.458862 -4.467468  7.217712  0.019226
# 1  8.465576 -4.466553  7.217102  0.019531
# 2  8.467407 -4.466553  7.214050  0.020447
# 3  8.469238 -4.464722  7.217407  0.021973
# 4  8.464355 -4.467773  7.214966  0.018616

# %%
# Out:
# 0          8.458862
# 1          8.465576
# 2          8.467407
# 3          8.469238
# 4          8.464355
#              ...
# 1279995    7.677917
# 1279996    7.694397
# 1279997    7.703247
# 1279998    7.700195
# 1279999    7.695923
# Name: 0, Length: 1280000, dtype: float64

# %%
plt.figure(figsize=(30,6))
sbn.lineplot(base.iloc[:1000,0])
# Out:
# <Axes: ylabel='0'>

# %%
plt.figure(figsize=(30,6))
sbn.lineplot(base.iloc[1000:2000,0])
# Out:
# <Axes: ylabel='0'>
